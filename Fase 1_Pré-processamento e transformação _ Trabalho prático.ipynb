# %%
import pandas as pd

# %%
data=pd.read_excel('Execução das despesas_Com seleção de atributos.xlsx', index_col=0)

# %%
data["UF"].fillna("Nascional", inplace = True)

# %%
data["Município"].fillna("Brasil", inplace = True)

# %%
data.dtypes
# Out:
# Nome Órgão Superior                     object
# Nome Órgão Subordinado                  object
# Nome Unidade Gestora                    object
# Nome Função                             object
# Nome Programa Orçamentário              object
# Nome Programa Governo                   object
# UF                                      object
# Município                               object
# Nome Autor Emenda                       object
# Nome Categoria Econômica                object
# Nome Elemento de Despesa                object
# Valor Empenhado (R$)                   float64
# Valor Liquidado (R$)                   float64
# Valor Pago (R$)                        float64
# Valor Restos a Pagar Inscritos (R$)    float64
# Valor Restos a Pagar Cancelado (R$)    float64
# Valor Restos a Pagar Pagos (R$)        float64
# ORÇAMENTO INICIAL (R$)                 float64
# ORÇAMENTO REALIZADO (R$)               float64
# dtype: object

# %%
data
# Out:
#                               Nome Órgão Superior  \
# Ano e mês do lançamento
# 2020/01                    Ministério da Educação
# 2020/01                      Ministério da Defesa
# 2020/01                    Ministério da Economia
# 2020/01                  Presidência da República
# 2020/01                    Ministério da Economia
# ...                                           ...
# 2020/12                      Ministério da Defesa
# 2020/12                            Sem informação
# 2020/12                    Ministério da Educação
# 2020/12                    Ministério da Educação
# 2020/12                      Ministério da Defesa
#
#                                              Nome Órgão Subordinado  \
# Ano e mês do lançamento
# 2020/01                               Instituto Federal Catarinense
# 2020/01                                         Comando do Exército
# 2020/01                         Instituto Nacional do Seguro Social
# ...

# %%
data['Nome Órgão Superior'].unique()
# Out:
# array(['Ministério da Educação', 'Ministério da Defesa',
#        'Ministério da Economia', 'Presidência da República',
#        'Ministério da Justiça e Segurança Pública',
#        'Ministério das Comunicações', 'Ministério da Saúde',
#        'Ministério da Ciência, Tecnologia, Inovações ',
#        'Ministério de Minas e Energia',
#        'Ministério das Relações Exteriores',
#        'Ministério da Infraestrutura',
#        'Ministério do Desenvolvimento Regional',
#        'Ministério da Agricultura, Pecuária e Abastec',
#        'Ministério do Meio Ambiente', 'Ministério da Cidadania',
#        'Ministério do Turismo',
#        'Ministério da Mulher, Família e Direitos Huma', 'Sem informação',
#        'Advocacia-Geral da União', 'Controladoria-Geral da União'],
#       dtype=object)
